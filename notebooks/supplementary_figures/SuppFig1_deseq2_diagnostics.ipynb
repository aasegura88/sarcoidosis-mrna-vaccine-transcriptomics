# %% [markdown]
# ### Supplementary Figure 1 | Differential expression model diagnostics and fold-change shrinkage
# DESeq2 diagnostic plots and log₂ fold-change shrinkage illustrate model fit and variance moderation.
