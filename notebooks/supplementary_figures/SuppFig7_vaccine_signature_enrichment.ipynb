# %% [markdown]
# ### Supplementary Figure 7 | Curated vaccine-response signatures exhibit dose-dependent enrichment patterns
# Enrichment of curated vaccine-response and Reactome pathways illustrates dose-dependent immune engagement.
