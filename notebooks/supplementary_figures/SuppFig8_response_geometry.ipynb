# %% [markdown]
# ### Supplementary Figure 8 | Sarcoidosis responses occupy an interferon-skewed transcriptomic response space
# Geometric analyses of transcriptomic response vectors characterize response magnitude and directional bias.
