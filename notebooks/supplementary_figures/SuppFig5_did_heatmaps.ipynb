# %% [markdown]
# ### Supplementary Figure 5 | Structured gene modules emerge in difference-in-differences contrasts
# Heatmap visualization of interaction effects highlights coherent gene modules across vaccination contrasts.
