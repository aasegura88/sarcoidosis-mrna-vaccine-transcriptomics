# %% [markdown]
# ### Supplementary Figure 9 | Inferred immune-cell proportions vary with deconvolution reference choice
# Comparison of deconvolution reference matrices demonstrates sensitivity of inferred immune-cell proportions.
