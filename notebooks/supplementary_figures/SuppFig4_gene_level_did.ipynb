# %% [markdown]
# ### Supplementary Figure 4 | Gene-level difference-in-differences analyses reveal distributed transcriptional effects
# Gene-level difference-in-differences contrasts show diffuse, low-magnitude transcriptional responses to vaccination.
